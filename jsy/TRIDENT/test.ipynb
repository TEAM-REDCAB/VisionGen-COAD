# %%
import h5py

# 정확한 파일 경로는 생성된 h5_files 폴더 내의 .h5 파일을 지정하세요.
h5_path = "trident_processed/20x_256px_0px_overlap/features_uni_v2/TCGA-AA-3939-01Z-00-DX1.6ceb6e8f-a469-4f42-9597-8bf853d95640.h5"

with h5py.File(h5_path, 'r') as f:
    print("Keys in H5:", list(f.keys()))
    features = f['features'][:]
    coords = f['coords'][:]
    
    print(f"특징 벡터 차원: {features.shape}") # (패치개수, 1024) 예상
    print(f"좌표 데이터 차원: {coords.shape}")     # (패치개수, 2) 예상
# Out:
# Keys in H5: ['coords', 'features']
# 특징 벡터 차원: (2043, 1536)
# 좌표 데이터 차원: (2043, 2)
